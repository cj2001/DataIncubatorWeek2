# %% [markdown]
# # Automated Snow Coverage Analysis with LANDSAT Data
# ## by Clair J. Sullivan

# %% [markdown]
# ### Check out my prior video for more info: https://www.youtube.com/watch?v=-nek6KLB5nI

# %%
# %matplotlib inline

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
im2 = cv2.imread('image_b2.tif',0)
im5 = cv2.imread('image_b5.tif',0)

# %% [markdown]
# ## LANDSAT Band 2 (Green) for region around Powder Mountain, Utah

# %%
plt.imshow(im2, cmap = 'gray')
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f4e09c317e8>

# %% [markdown]
# ##LANDSAT Band 5 (SWIR) for region around Powder Mountain, Utah

# %%
plt.imshow(im5, cmap = 'gray')
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f4dec595a70>

# %% [markdown]
# ## Normalized Difference Snow Index (NDSI) for LANDSAT Imagery

# %% [markdown]
# $$NDSI = \frac{Band_{2} - Band_{5}}{Band_{2} + Band_{5}}$$

# %%
base = np.ones(im2.shape)
im2n = im2 + base
im5n = im5 + base

num = np.absolute(im2n - im5n)
denom = im2n + im5n
ndsi = np.divide(num,denom)

plt.imshow(ndsi, cmap='gray')
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f4dec401b90>

# %% [markdown]
# Studies have shown you can differentiate between snow and non-snow by thresholding NDSI > 0.4.  However, this can vary based on water content in the snow, grain size of snow, etc.

# %%
tndsi = ndsi > 0.4
plt.imshow(tndsi, cmap='gray')
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f4dec276290>

# %%
tndsi = ndsi > 0.6
plt.imshow(tndsi, cmap='gray')
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f4dec0e4e18>
